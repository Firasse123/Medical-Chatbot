# %%
from langchain import PromptTemplate
from langchain.chains import RetrievalQA
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Pinecone
import pinecone
from langchain.document_loaders import PyMuPDFLoader,DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.prompts import PromptTemplate

# %%
from ollama import chat

response = chat(
    model='llama3.1:latest',
    messages=[{'role': 'user', 'content': 'Explain the theory of relativity in simple terms.'}]
)

print(response.message.content)
# Out:
# One of the most mind-bending and fascinating theories in physics! The theory of relativity, developed by Albert Einstein, can be explained in simple terms as follows:
#
# **What is time and space?**
#
# In everyday life, we think of time and space as separate things. Time is what allows us to measure how long it takes for events to happen (e.g., "I'll meet you at 5 PM"). Space is the three-dimensional world around us where objects exist and move.
#
# **The problem: absolute time and space**
#
# Classical physics, developed by Isaac Newton, assumed that there was an absolute time and space. This meant that everyone on Earth could agree on what time it was and how far apart things were, regardless of their relative motion.
#
# **Enter Einstein's theory of relativity**
#
# Einstein challenged this idea with his special theory of relativity (1905) and general theory of relativity (1915). He showed that:
#
# 1. **Time is not absolute**: Time can appear to slow down or speed up depending on an object's velocity. This means that two observers in motion relative to each other may measure time differently.
# 2. **Space is not fixed**: Space is flexible and dependent on the observer's frame of reference. Distance between objects can vary depending on their relative motion.
#
# **The key concepts:**
#
# 1. **Time dilation**: The faster you move, the slower time passes for you compared to someone who is standing still. This effect becomes significant at high speeds (approaching the speed of light).
# 2. **Length contraction**: As an object approaches the speed of light, its length appears shorter to an observer who is standing still.
# 3. **Relativity of simultaneity**: Two events that are simultaneous for one observer may not be simultaneous for another observer in a different frame of reference.
#
# **What does this mean?**
#
# The theory of relativity revolutionized our understanding of space and time. It:
#
# 1. **Challenged the notion of absolute truth**: Time and space are relative, not fixed.
# 2. **Showed that motion is relative**: The laws of physics remain the same for all observers in uniform motion relative to each other.
# 3. **Predicted phenomena like gravitational time dilation**: Time appears to slow down near massive objects due to their strong gravitational fields.
#
# The theory of relativity has been extensively tested and confirmed through experiments, observations, and technological advancements. It forms a cornerstone of modern physics, influencing our understanding of the universe from tiny particles to black holes.

# %%
PINECONE_API_KEY="pcsk_3d9JgD_HFPeXmm8Pb8rj1Hw4Pwv1bn6kPfVkvWKJyvvHMR2RUSTV1pMGJrFTsP5df8i6b"

# %%
#extract data from pdf
def load_pdf(data):
    loader=DirectoryLoader(data,
                    glob="*.pdf",
                    loader_cls=PyMuPDFLoader)
    documents=loader.load()
    return documents
# Out:
# 1.10.24
